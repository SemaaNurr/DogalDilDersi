# %%
import pandas as pd

# Örnek model isimleri
models = [
    'tfidf_lemmatized',
    'word2vec_stemmed_cbow_win2_dim100'
]

# Örnek en benzer 5 metin ID'leri (doc1, doc2 vb.)
benzer_metnler = [
    ['doc1', 'doc5', 'doc10', 'doc15', 'doc20'],
    ['doc3', 'doc6', 'doc9', 'doc12', 'doc18']
]

# Örnek anlamsal puanlar (manuel olarak sen değiştireceksin)
puanlar = [
    [4, 4, 3, 5, 4],
    [2, 3, 2, 3, 1]
]

# Ortalama puanlar hesapla
ortalama_puanlar = [sum(p)/len(p) for p in puanlar]

# DataFrame oluştur
df = pd.DataFrame({
    'Model Adı': models,
    '5 Benzer Metin': [', '.join(metinler) for metinler in benzer_metnler],
    'Skorlar': [', '.join(map(str, p)) for p in puanlar],
    'Ortalama Puan': ortalama_puanlar
})

print(df)

# CSV olarak kaydetmek istersen
df.to_csv('anlamsal_degerlendirme.csv', index=False)
import pandas as pd

# Örnek model isimleri
models = [
    'tfidf_lemmatized',
    'word2vec_stemmed_cbow_win2_dim100'
]

# Örnek en benzer 5 metin ID'leri (doc1, doc2 vb.)
benzer_metnler = [
    ['doc1', 'doc5', 'doc10', 'doc15', 'doc20'],
    ['doc3', 'doc6', 'doc9', 'doc12', 'doc18']
]

# Örnek anlamsal puanlar (manuel olarak sen değiştireceksin)
puanlar = [
    [4, 4, 3, 5, 4],
    [2, 3, 2, 3, 1]
]

# Ortalama puanlar hesapla
ortalama_puanlar = [sum(p)/len(p) for p in puanlar]

# DataFrame oluştur
df = pd.DataFrame({
    'Model Adı': models,
    '5 Benzer Metin': [', '.join(metinler) for metinler in benzer_metnler],
    'Skorlar': [', '.join(map(str, p)) for p in puanlar],
    'Ortalama Puan': ortalama_puanlar
})

print(df)
# Out:
#                            Model Adı                   5 Benzer Metin  \
# 0                   tfidf_lemmatized  doc1, doc5, doc10, doc15, doc20
# 1  word2vec_stemmed_cbow_win2_dim100   doc3, doc6, doc9, doc12, doc18
#
#          Skorlar  Ortalama Puan
# 0  4, 4, 3, 5, 4            4.0
# 1  2, 3, 2, 3, 1            2.2
#                            Model Adı                   5 Benzer Metin  \
# 0                   tfidf_lemmatized  doc1, doc5, doc10, doc15, doc20
# 1  word2vec_stemmed_cbow_win2_dim100   doc3, doc6, doc9, doc12, doc18
#
#          Skorlar  Ortalama Puan
# 0  4, 4, 3, 5, 4            4.0
# 1  2, 3, 2, 3, 1            2.2
